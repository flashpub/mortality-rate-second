# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("all-causes.csv")
df.drop(['Age Group','Percentage of cause-specific deaths out of total deaths'], axis=1, inplace=True)

# %%
#cleaning the data frame
df_reduced = pd.DataFrame()
df_reduced = df[(df['Year'] > 1959) & (df['Year'] < 2020)]
df_reduced = df_reduced[df_reduced['Age group code'] != 'Age_unknown']
df_reduced = df_reduced.rename(columns={'Death rate per 100 000 population':'Death rate'})
unique_countries = df_reduced['Country Code'].unique()
unique_years = df_reduced['Year'].unique()
print(f'number of countries is {len(unique_countries)} and number of years is {len(unique_years)}')

df_reduced['Country Code'].unique()
# Out:
# number of countries is 118 and number of years is 60
# array(['ALB', 'ATG', 'ARG', 'ARM', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR',
#        'BRB', 'BLR', 'BEL', 'BLZ', 'BIH', 'BRA', 'BRN', 'BGR', 'CPV',
#        'CAN', 'CHL', 'COL', 'CRI', 'HRV', 'CUB', 'CYP', 'CZE', 'DNK',
#        'DMA', 'DOM', 'ECU', 'EGY', 'SLV', 'EST', 'FJI', 'FIN', 'FRA',
#        'GUF', 'GEO', 'DEU', 'GRC', 'GRD', 'GLP', 'GTM', 'GUY', 'HKG',
#        'HUN', 'ISL', 'IRN', 'IRQ', 'IRL', 'ISR', 'ITA', 'JAM', 'JPN',
#        'KAZ', 'KOR', 'KWT', 'KGZ', 'LVA', 'LTU', 'LUX', 'MDV', 'MLT',
#        'MTQ', 'MUS', 'MYT', 'MEX', 'MDA', 'MNG', 'MNE', 'NLD', 'NZL',
#        'NIC', 'MKD', 'NOR', 'PAN', 'PRY', 'PER', 'PHL', 'POL', 'PRT',
#        'PRI', 'REU', 'ROU', 'RUS', 'KNA', 'LCA', 'VCT', 'STP', 'SRB',
#        'SYC', 'SGP', 'SVK', 'SVN', 'ZAF', 'ESP', 'LKA', 'SUR', 'SWE',
#        'CHE', 'SYR', 'TJK', 'THA', 'TTO', 'TUR', 'TKM', 'UKR', 'GBR',
#        'USA', 'URY', 'UZB', 'VEN', 'JOR', 'ARE', 'LBN', 'MYS', 'OMN',
#        'QAT'], dtype=object)

# %%
#USA is deleted because it doesn't have age specific numbers in 2009
df_reduced[(df_reduced['Country Code'] == "USA") & (df_reduced['Death rate'].isna() == True)]
# Out:
#        Region Code                      Region Name Country Code  \
# 262374         NAC  North America and the Caribbean          USA
# 262375         NAC  North America and the Caribbean          USA
# 262376         NAC  North America and the Caribbean          USA
# 262377         NAC  North America and the Caribbean          USA
# 262378         NAC  North America and the Caribbean          USA
# 262379         NAC  North America and the Caribbean          USA
# 262380         NAC  North America and the Caribbean          USA
# 262381         NAC  North America and the Caribbean          USA
# 262382         NAC  North America and the Caribbean          USA
# 262383         NAC  North America and the Caribbean          USA
# 262384         NAC  North America and the Caribbean          USA
# 262385         NAC  North America and the Caribbean          USA
# 262386         NAC  North America and the Caribbean          USA
# 262387         NAC  North America and the Caribbean          USA
# 262388         NAC  North America and the Caribbean          USA
# 262389         NAC  North America and the Caribbean          USA
# 262390         NAC  North America and the Caribbean          USA
# 262391         NAC  North America and the Caribbean          USA
# 262392         NAC  North America and the Caribbean          USA
# 262393         NAC  North America and the Caribbean          USA
#
#                     Country Name  Year      Sex Age group code  Number  \
# 262374  United States of America  2009  Unknown     Age85_over     0.0
# 262375  United States of America  2009  Unknown        Age_all     2.0
# 262376  United States of America  2009  Unknown          Age00     0.0
# 262377  United States of America  2009  Unknown       Age01_04     0.0
# 262378  United States of America  2009  Unknown       Age05_09     0.0
# 262379  United States of America  2009  Unknown       Age10_14     0.0
# 262380  United States of America  2009  Unknown       Age15_19     0.0
# 262381  United States of America  2009  Unknown       Age20_24     0.0
# 262382  United States of America  2009  Unknown       Age25_29     0.0
# 262383  United States of America  2009  Unknown       Age30_34     0.0
# 262384  United States of America  2009  Unknown       Age35_39     0.0
# 262385  United States of America  2009  Unknown       Age40_44     0.0
# 262386  United States of America  2009  Unknown       Age45_49     0.0
# 262387  United States of America  2009  Unknown       Age50_54     0.0
# 262388  United States of America  2009  Unknown       Age55_59     0.0
# 262389  United States of America  2009  Unknown       Age60_64     0.0
# 262390  United States of America  2009  Unknown       Age65_69     1.0
# 262391  United States of America  2009  Unknown       Age70_74     0.0
# 262392  United States of America  2009  Unknown       Age75_79     0.0
# 262393  United States of America  2009  Unknown       Age80_84     0.0
#
#         Age-standardized death rate per 100 000 standard population  \
# 262374                                                NaN
# 262375                                                NaN
# 262376                                                NaN
# 262377                                                NaN
# 262378                                                NaN
# 262379                                                NaN
# 262380                                                NaN
# 262381                                                NaN
# 262382                                                NaN
# 262383                                                NaN
# 262384                                                NaN
# 262385                                                NaN
# 262386                                                NaN
# 262387                                                NaN
# 262388                                                NaN
# 262389                                                NaN
# 262390                                                NaN
# 262391                                                NaN
# 262392                                                NaN
# 262393                                                NaN
#
#         Death rate
# 262374         NaN
# 262375         NaN
# 262376         NaN
# 262377         NaN
# 262378         NaN
# 262379         NaN
# 262380         NaN
# 262381         NaN
# 262382         NaN
# 262383         NaN
# 262384         NaN
# 262385         NaN
# 262386         NaN
# 262387         NaN
# 262388         NaN
# 262389         NaN
# 262390         NaN
# 262391         NaN
# 262392         NaN
# 262393         NaN

# %%
# removing countries with NAN Death rate
removable_countries = df_reduced[df_reduced['Death rate'].isna() == True ]['Country Code'].unique().tolist()
df_reduced = df_reduced[df_reduced['Country Code'].apply(lambda x: x not in removable_countries)]
unique_countries = df_reduced['Country Code'].unique()
unique_years = df_reduced['Year'].unique()
print(f'number of rows : {len(df_reduced)} , number of countries : {len(unique_countries)}, number of years : {len(unique_years)}')
# Out:
# number of rows : 157980 , number of countries : 69, number of years : 60

# %%
years = unique_years.tolist()
countries = df_reduced['Country Code'].unique().tolist()
complete_countries = []
for c in countries:
   if sorted(df_reduced[df_reduced['Country Code'] == c]['Year'].unique().tolist()) == sorted(unique_years.tolist()):
    complete_countries.append(c)
df_reduced = df_reduced[df_reduced['Country Code'].apply(lambda x: x in complete_countries)]
unique_countries = df_reduced['Country Code'].unique()
unique_years = df_reduced['Year'].unique()
print(f'number of rows : {len(df_reduced)} , number of countries : {len(unique_countries)}, number of years : {len(unique_years)}')
# Out:
# number of rows : 39600 , number of countries : 11, number of years : 60

# %%
# countries to work with
df_reduced['Country Code'].unique()
# Out:
# array(['AUT', 'DNK', 'FIN', 'HUN', 'ISL', 'ITA', 'JPN', 'NLD', 'ESP',
#        'CHE', 'GBR'], dtype=object)

# %%
#final data frame
df_reduced
# Out:
#        Region Code Region Name Country Code Country Name  Year     Sex  \
# 13356           EU      Europe          AUT      Austria  1960     All
# 13358           EU      Europe          AUT      Austria  1960     All
# 13359           EU      Europe          AUT      Austria  1960     All
# 13360           EU      Europe          AUT      Austria  1960     All
# 13361           EU      Europe          AUT      Austria  1960     All
# ...            ...         ...          ...          ...   ...     ...
# 298657          EU      Europe          NLD  Netherlands  2015  Female
# 298658          EU      Europe          NLD  Netherlands  2015  Female
# 298659          EU      Europe          NLD  Netherlands  2015  Female
# 298660          EU      Europe          NLD  Netherlands  2015  Female
# 298661          EU      Europe          NLD  Netherlands  2015  Female
#
#        Age group code   Number  \
# 13356        Age75_79  14097.0
# 13358        Age80_84  12241.0
# 13359         Age_all  89603.0
# 13360           Age00   4727.0
# 13361        Age01_04    700.0
# ...               ...      ...
# 298657       Age55_59   2377.0
# 298658       Age60_64   3408.0
# 298659       Age75_79   7822.0
# 298660       Age80_84  12066.0
# 298661     Age85_over  35722.0
#
#         Age-standardized death rate per 100 000 standard population  \
# 13356                                                 NaN
# 13358                                                 NaN
# 13359                                          987.228139
# 13360                                                 NaN
# 13361                                                 NaN
# ...                                                   ...
# 298657                                                NaN
# 298658                                                NaN
# 298659                                                NaN
# 298660                                                NaN
# 298661                                                NaN
#
#           Death rate
# 13356    8517.824773
# 13358   13941.913440
# 13359    1271.415396
# 13360    3900.165017
# 13361     155.936734
# ...              ...
# 298657    409.603717
# 298658    648.219299
# 298659   2613.702054
# 298660   5206.674693
# 298661  14940.379850
#
# [39600 rows x 10 columns]
